# %%
import tensorflow as tf
from PIL import Image
import cv2 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data.csv", index_col=0)

# %%
import os
images = sorted(list(filter(lambda x:(x.endswith("png") or x.endswith("jpg")) and x not in df.Image.tolist(), os.listdir("sudoku images"))), key=len)

# %% [markdown]
# cnt = []
# for i in df.Image:
#     a = cv2.imread(os.path.join("sudoku images", i), 0)
#     if a.shape != (480, 640):
#         a = cv2.resize(a, (480, 640))
#     if a.shape == (480, 640):
#         cnt.append(i)
#
# df = df[[i in cnt for i in df.Image ]]

# %%
i = len(df)

# %%
img = cv2.imread(os.path.join("sudoku images", images[i]), 0)
if img.shape != (480, 640):
    img = cv2.resize(img, (640, 480))

# %%
img.shape
# Out:
# (480, 640)

# %%
# %matplotlib notebook
plt.imshow(img)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
points = []
def point_put(event, x, y, flags, params):
    global points
    if event == cv2.EVENT_LBUTTONDOWN:
        points += [(x,y)]
cv2.namedWindow('image',cv2.WINDOW_NORMAL)
cv2.setMouseCallback('image',point_put)
while(1):
    cv2.imshow('image',img)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %%
if len(points) != 16:
    print("Inaccurate Points")
else:
    print("OK")
# Out:
# OK

# %%
df = df.append({"Image":images[i], "Points":str(points)}, ignore_index=True)

# %%
df.to_csv("Data.csv")

# %%
X = list()
for i in [cv2.imread(os.path.join("sudoku images", i), 0) for i in df.Image]:
    
    X.append(cv2.resize(i,(640, 480)))

# %%
y = [np.array(eval(i)) for i in df.Points]

# %%
X = np.array(X).reshape(-1, 480, 640, 1)

# %%
y = np.array(y )

# %%
X.shape, y.shape
# Out:
# ((83, 480, 640, 1), (83, 16, 2))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

model.add(Conv2D(10,(3, 4), activation='linear',  input_shape=(480, 640, 1)))

model.add(Conv2D(20, (3, 4), activation='linear'))

model.add(Conv2D(20, (3, 4), activation='linear'))
model.add(Conv2D(20, (3, 4), activation='linear'))
model.add(MaxPool2D((2, 3)))
model.add(Conv2D(20, (3, 4), activation='linear'))
model.add(MaxPool2D((3, 4)))
model.add(Conv2D(10, (3, 4), activation='linear'))
model.add(MaxPool2D((2, 4)))
model.add(Conv2D(40, (4, 5), activation='linear'))
model.add(MaxPool2D((2, 4)))

model.add(Conv2D(1, (2, 1 ), activation='linear'))
model.compile(loss='mean_squared_error', optimizer=Adam(.5) )

# %%
model.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_168 (Conv2D)          (None, 478, 637, 10)      130
# _________________________________________________________________
# conv2d_169 (Conv2D)          (None, 476, 634, 20)      2420
# _________________________________________________________________
# conv2d_170 (Conv2D)          (None, 474, 631, 20)      4820
# _________________________________________________________________
# conv2d_171 (Conv2D)          (None, 472, 628, 20)      4820
# _________________________________________________________________
# max_pooling2d_83 (MaxPooling (None, 236, 209, 20)      0
# _________________________________________________________________
# conv2d_172 (Conv2D)          (None, 234, 206, 20)      4820
# _________________________________________________________________
# max_pooling2d_84 (MaxPooling (None, 78, 51, 20)        0
# _________________________________________________________________
# conv2d_173 (Conv2D)          (None, 76, 48, 10)        2410
# _________________________________________________________________
# max_pooling2d_85 (MaxPooling (None, 38, 12, 10)        0
# _________________________________________________________________
# conv2d_174 (Conv2D)          (None, 35, 8, 40)         8040
# _________________________________________________________________
# max_pooling2d_86 (MaxPooling (None, 17, 2, 40)         0
# _________________________________________________________________
# conv2d_175 (Conv2D)          (None, 16, 2, 1)          81
# =================================================================
# Total params: 27,541
# Trainable params: 27,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=X, y=y, epochs=50,batch_size=10)
# Out:
# Train on 83 samples
# Epoch 1/50
# 70/83 [========================>.....] - ETA: 9s - loss: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-b9fe5f3b914d> in <module>
# ----> 1 history = model.fit(x=X, y=y, epochs=50,batch_size=10)
#
# c:\users\dell\desktop\python~1\machin~2\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# c:\users\dell\desktop\python~1\machin~2\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# c:\users\dell\desktop\python~1\machin~2\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# c:\users\dell\desktop\python~1\machin~2\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# c:\users\dell\desktop\python~1\machin~2\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# c:\users\dell\desktop\python~1\machin~2\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# c:\users\dell\desktop\python~1\machin~2\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# c:\users\dell\desktop\python~1\machin~2\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# c:\users\dell\desktop\python~1\machin~2\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# c:\users\dell\desktop\python~1\machin~2\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# c:\users\dell\desktop\python~1\machin~2\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
